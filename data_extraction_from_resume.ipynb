# %%
pip install pdfminer
# Out:
# Collecting pdfminerNote: you may need to restart the kernel to use updated packages.
#   Downloading pdfminer-20191125.tar.gz (4.2 MB)
# Collecting pycryptodome
#   Downloading pycryptodome-3.10.1-cp35-abi3-win_amd64.whl (1.6 MB)
# Building wheels for collected packages: pdfminer
#   Building wheel for pdfminer (setup.py): started
#   Building wheel for pdfminer (setup.py): finished with status 'done'
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140124 sha256=4c7cc47f7636d7ced3bebea919f6ead466fe02e728d3d84784b6770cb57a1330
#   Stored in directory: c:\users\sruthi\appdata\local\pip\cache\wheels\1c\28\7d\f390b82bb0307deb63ff27a1474fd308ec68ee028cb9ab6283
# Successfully built pdfminer
# Installing collected packages: pycryptodome, pdfminer
# Successfully installed pdfminer-20191125 pycryptodome-3.10.1

# %%
pip install docx2txt
# Out:
# Requirement already satisfied: docx2txt in c:\users\sruthi\anaconda3\lib\site-packages (0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install doc2text
# Out:
# Collecting doc2text
#   Downloading doc2text-0.2.4.tar.gz (21 kB)
# Collecting PyPDF2
# Note: you may need to restart the kernel to use updated packages.
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
# Requirement already satisfied: numpy in c:\users\sruthi\anaconda3\lib\site-packages (from doc2text) (1.19.5)
# Requirement already satisfied: Pillow in c:\users\sruthi\anaconda3\lib\site-packages (from doc2text) (7.2.0)
# Requirement already satisfied: scipy in c:\users\sruthi\anaconda3\lib\site-packages (from doc2text) (1.5.0)
# Collecting pytesseract
#   Downloading pytesseract-0.3.8.tar.gz (14 kB)
# Collecting mime
#   Downloading mime-0.1.0.tar.gz (32 kB)
# Requirement already satisfied: future in c:\users\sruthi\anaconda3\lib\site-packages (from mime->doc2text) (0.18.2)
# Building wheels for collected packages: doc2text, PyPDF2, pytesseract, mime
#   Building wheel for doc2text (setup.py): started
#   Building wheel for doc2text (setup.py): finished with status 'done'
#   Created wheel for doc2text: filename=doc2text-0.2.4-py2.py3-none-any.whl size=8407 sha256=873bc2f8b0261c939bf9bce53b6eea5ded916269c87ef1f69ee4b2b6c6c2eafe
#   Stored in directory: c:\users\sruthi\appdata\local\pip\cache\wheels\af\53\38\d0451e77981eff7ae9d4a96abbe19e28a8a42bf4f9f7e93aec
#   Building wheel for PyPDF2 (setup.py): started
#   Building wheel for PyPDF2 (setup.py): finished with status 'done'
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61085 sha256=dbeb602a65f0ec3307cf60795ef8f64b901a40b16159ae8f98a5afccd79aaee7
#   Stored in directory: c:\users\sruthi\appdata\local\pip\cache\wheels\b1\1a\8f\a4c34be976825a2f7948d0fa40907598d69834f8ab5889de11
#   Building wheel for pytesseract (setup.py): started
#   Building wheel for pytesseract (setup.py): finished with status 'done'
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14065 sha256=6f0ba3e7a85a531fd36216dda6d1730bd48fe6e69333881afa3f5dc5b16c8f35
#   Stored in directory: c:\users\sruthi\appdata\local\pip\cache\wheels\ed\8a\c6\40c7ec06c2dd3df636832537238128a1471bf9c1b6a3a9bf40
#   Building wheel for mime (setup.py): started
#   Building wheel for mime (setup.py): finished with status 'done'
#   Created wheel for mime: filename=mime-0.1.0-py3-none-any.whl size=39040 sha256=dd5c1dc2b42168370222520087b59e9a50d40a49b6b1854ffd9a31cc26004ce8
#   Stored in directory: c:\users\sruthi\appdata\local\pip\cache\wheels\50\9c\43\9cd8d0040b8e1b7e6925bbf2e3beae8c649b1e358e05534548
# Successfully built doc2text PyPDF2 pytesseract mime
# Installing collected packages: PyPDF2, pytesseract, mime, doc2text
# Successfully installed PyPDF2-1.26.0 doc2text-0.2.4 mime-0.1.0 pytesseract-0.3.8

# %%
# Import libaries
import regex as re
import pdfminer
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import os
import docx2txt

# %%
# Uploading the pdf resume and reading resume  
rootdir = 'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb'
files = os.listdir(rootdir)
#print(files)
file_names = []
for file in os.listdir(rootdir):
    #print(os.path.join( file))
    file_names.append(os.path.join( 'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb',file))
file_names
# Out:
# ['C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AditiGupta[6_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Aishwarya[5_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AkankshitaSatapathy[7_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Akshaya[9_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\anantikalimboo[7_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AnithaSRathod[8_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AnkitaMakwana[7_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AnshuPanjwani[6_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AnupamKumari[5_5].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AnushaSRao[6_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\ArockiaJecinthaJames[12_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\AsmitaKumari[4_2].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Asmita[8_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\BandanaBastia[7_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\BhavanaKV[6_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\BindhuMuralidhara[5_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\ChristinaP[2_11].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Confidential[5_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\DeepalakshmiNatarajan[7_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\DeepaliJha[7_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Deepika[5_6].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\DivyaB[5_4].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\education.txt',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\extracted_data.xlsx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\GarimaRathore[5_10].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\GowthamiDhanabalu[7_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\GraceFreeda[6_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\grishmashah[6_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\IshaChoudhari[10_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\JayashriM[5_5].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\JisFrancis[5_1].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\KalyaniMolugu[9_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\KavyaNalam[8_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\KAVYASHREE[5_6].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\KomalKishore[8_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Lakshmi[14_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\LathaB[3_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\LuckyGupta[3_8].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\MadhaviKunchala[5_8].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\MadhuriDesai[3_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\MANISHAKUMARI[3_8].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\MeghaHajeri[14_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\MehakMandhana[3_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\MITALI[6_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\monika[3_2].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Narmada[3_2].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Naveena[3_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\NeethuDominic[8_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\NehaGupta[4_11].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\NirdhiJaiswal[5_3].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\NISHCHITAPURUSHOTHAMAPATEL[4_6].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\NishthaMathur[2_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\pallawipriya[7_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PandrankiDivyaBharathi[8_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PoojaKoushik[6_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PragatiBharti[5_1].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PrajaktaSolkar[3_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PrakruthiV[6_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PreethikiranmaiKomarapu[5_5].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\PreetySingh[4_4].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Radha[3_11].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Ranjitha[4_11].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\RESHMABHAGAT[1_4].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\Sahera[5_1].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\sameerashaik[9_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SankaSatyaRajavalliManasa[4_1].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SaumyaSuman[7_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\ShaluSharma[4_7].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\ShreyaDhingra[5_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SHRUTIPRIYA[3_7].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\snehalpawar[9_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SnigdhaJha[6_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SnigdharaniPatra[5_5].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SoumyaSharma[4_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SowmyaJyothi[8_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SrujanaM[5_9].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SruthyRaj[8_0].doc',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SubhasmitaPanda[5_10].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SuchismitaMukherjee[5_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SulataSadhu[6_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SumitSinghal[4_9].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\suryasnatanaik[3_5].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\susmita[8_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\swapna[3_6].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SwarnaHarisantha[3_0].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SwathiAdari[3_2].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\SwatiSinha[5_3].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\tejaswitamultani[3_3].pdf',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\ThirumalaVaishnavi[3_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\valid_skills.txt',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\VatrapuVijayaRamaLakshmi[5_2].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\VijayaLakshmiPullari[3_0].docx',
#  'C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\\YaminiVerma[3_8].pdf']

# %%
# Split all the resume line based on reqruirements
def open_pdf_file(file_name):
    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    pagenums = set()
    infile = open(file_name, 'rb')
    for page in PDFPage.get_pages(infile, pagenums):
        interpreter.process_page(page)
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close()

    result = []

    for line in text.split('\n'):
        line2 = line.strip()
        if line2 != '':
            result.append(line2)
    return (result)

# %%
# Converting the resume to text 
def open_docx_file(file_name):
    temp = docx2txt.process(file_name)
    text = [line.replace('\t', ' ') for line in temp.split('\n') if line]
    text = [t for t in text if len(t) > 1]
    return (text)

# %%
# Removing Punctuations from resume 
def remove_punctuations(line):
    return re.sub(r'(\.|\,)', '', line)

def preprocess_document(document):
    for index, line in enumerate(document):
        line = line.lower()
        line = remove_punctuations(line)
        
        line = line.split(' ')
        while '' in line:
            line.remove('')
            
        while ' '  in line:
            line.remove(' ')
            
            
        document[index] = ' '.join(line)
    return (document)

# %%
# Extracting few more information from resume(phone_no)
def get_phone_no(document):
    #This function has to be further modified better and accurate results.
    #Possible phone number formats - Including +91 or just with the numbers.
    
    mob_num_regex = r'''(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)
                        [-\.\s]*\d{3}[-\.\s]??\d{4}|\d{5}[-\.\s]??\d{4})'''
    pattern = re.compile(mob_num_regex)
    matches = []
    for line in document:
        match = pattern.findall(line)
        for mat in match:
            if len(mat) > 9:
                matches.append(mat)

    return (matches)

# %%
# Extracting education information from resume:
def get_education(document):
    education_terms = []
    with open('C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb/education.txt', 'r') as file:
        education_terms = file.readlines()
    
    education_terms = [term.strip('\n') for term in education_terms]
    education = []
    for line in document:
        for word in line.split(' '):
            if len(word) > 2 and word in education_terms:
                if line not in education:
                    education.append(line)
    #print (education)
    return (education)

# %%
## Extracting Skill information from resume:
def get_skills(document):
    skill_terms = []
    with open('C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb/valid_skills.txt', 'r') as file:
        skill_terms = file.readlines()
    
    skill_terms = [term.strip('\n') for term in skill_terms]
    skills = []
    
    for line in document:
        words = line.split(' ')
        
        for word in words:
            if word in skill_terms:
                if word not in skills:
                    skills.append(word)
                    
        word_pairs = []
        for i in zip(words[:-1], words[1:]):
            word_pairs.append(i[0] + ' ' + i[1])   #This is to find skills like 'data science' i.e skills containint two words.    return (skills)
            
        for pair in word_pairs:
            if pair in skill_terms:
                if pair not in skills:
                    skills.append(pair)
                    
    return (skills)

# %%
# Extracting experience information from resume:
def get_experience(document):
    pattern1 = re.compile(r'(jan(uary)?|feb(ruary)?|mar(ch)?|apr(il)?|may|jun(e)?|jul(y)?|aug(ust)?|sep(tember)?|oct(ober)?|nov(ember)?|dec(ember)?)(\s|\S)(\d{2,4}).*(jan(uary)?|feb(ruary)?|mar(ch)?|apr(il)?|may|jun(e)?|jul(y)?|aug(ust)?|sep(tember)?|oct(ober)?|nov(ember)?|dec(ember)?)(\s|\S)(\d{2,4})')
    pattern2 = re.compile(r'(\d{2}(.|..)\d{4}).{1,4}(\d{2}(.|..)\d{4})')
    pattern3 = re.compile(r'(\d{2}(.|..)\d{4}).{1,4}(present)')
    pattern4 = re.compile(r'(jan(uary)?|feb(ruary)?|mar(ch)?|apr(il)?|may|jun(e)?|jul(y)?|aug(ust)?|sep(tember)?|oct(ober)?|nov(ember)?|dec(ember)?)(\s|\S)(\d{2,4}).*(present)')
    patterns = [pattern1, pattern2, pattern3, pattern4]
    experience = []
    for index, line in enumerate(document):
        for pattern in patterns:
            exp = pattern.findall(line)
            if len(exp) > 0:
                experience.append(document[index:index+4])
                
    return (experience)

# %%
# Combining all the information from resume
phone_nos=[]
education_1 = []
education_2 = []
skills_1 = []
skills_2 = []
experience_1 = []
experience_2 = []

for file_name in file_names:
    print(file_name)
    if file_name.endswith('.pdf'):
        document = open_pdf_file(file_name)
    elif file_name.endswith('.docx'):
        document=open_docx_file(file_name)
    else:
        continue
        
    phone_no = get_phone_no(document)
    document = preprocess_document(document)
    if len(phone_no) > 0:
        phone_nos.append(phone_no[0])
    else:
        phone_nos.append('')
    education = get_education(document)
    #print ('Education ', get_education(document))
    if len(education) > 1:
        education_1.append(education[0])
        education_2.append(education[1])
    elif len(education) == 1:
        education_1.append(education[0])
        education_2.append('')
    elif len(education) == 0:
        education_1.append('')
        education_2.append('') 
    
        
    skills = get_skills(document)
    #print ('Skills ', skills)
    
    if len(skills) > 1:
        skills_1.append(skills[0])
        skills_2.append(skills[1])
    elif len(skills) == 1:
        skills_1.append(skills[0])
        skills_2.append('')
    elif len(skills) == 0:
        skills_1.append('')
        skills_2.append('')
        
    experience = get_experience(document)
    #print ('Experience ', get_experience(document))
    if len(experience) > 1:
        experience_1.append(experience[0])
        experience_2.append(experience[1])
    elif len(experience) == 1:
        experience_1.append(experience[0])
        experience_2.append('')
    elif len(experience) == 0:
        experience_1.append('')
        experience_2.append('')
# Out:
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AditiGupta[6_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Aishwarya[5_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AkankshitaSatapathy[7_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Akshaya[9_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\anantikalimboo[7_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AnithaSRathod[8_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AnkitaMakwana[7_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AnshuPanjwani[6_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AnupamKumari[5_5].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AnushaSRao[6_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\ArockiaJecinthaJames[12_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\AsmitaKumari[4_2].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Asmita[8_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\BandanaBastia[7_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\BhavanaKV[6_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\BindhuMuralidhara[5_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\ChristinaP[2_11].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Confidential[5_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\DeepalakshmiNatarajan[7_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\DeepaliJha[7_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Deepika[5_6].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\DivyaB[5_4].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\education.txt
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\extracted_data.xlsx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\GarimaRathore[5_10].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\GowthamiDhanabalu[7_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\GraceFreeda[6_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\grishmashah[6_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\IshaChoudhari[10_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\JayashriM[5_5].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\JisFrancis[5_1].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\KalyaniMolugu[9_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\KavyaNalam[8_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\KAVYASHREE[5_6].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\KomalKishore[8_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Lakshmi[14_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\LathaB[3_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\LuckyGupta[3_8].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\MadhaviKunchala[5_8].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\MadhuriDesai[3_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\MANISHAKUMARI[3_8].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\MeghaHajeri[14_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\MehakMandhana[3_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\MITALI[6_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\monika[3_2].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Narmada[3_2].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Naveena[3_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\NeethuDominic[8_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\NehaGupta[4_11].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\NirdhiJaiswal[5_3].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\NISHCHITAPURUSHOTHAMAPATEL[4_6].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\NishthaMathur[2_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\pallawipriya[7_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PandrankiDivyaBharathi[8_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PoojaKoushik[6_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PragatiBharti[5_1].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PrajaktaSolkar[3_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PrakruthiV[6_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PreethikiranmaiKomarapu[5_5].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\PreetySingh[4_4].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Radha[3_11].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Ranjitha[4_11].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\RESHMABHAGAT[1_4].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\Sahera[5_1].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\sameerashaik[9_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SankaSatyaRajavalliManasa[4_1].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SaumyaSuman[7_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\ShaluSharma[4_7].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\ShreyaDhingra[5_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SHRUTIPRIYA[3_7].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\snehalpawar[9_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SnigdhaJha[6_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SnigdharaniPatra[5_5].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SoumyaSharma[4_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SowmyaJyothi[8_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SrujanaM[5_9].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SruthyRaj[8_0].doc
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SubhasmitaPanda[5_10].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SuchismitaMukherjee[5_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SulataSadhu[6_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SumitSinghal[4_9].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\suryasnatanaik[3_5].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\susmita[8_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\swapna[3_6].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SwarnaHarisantha[3_0].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SwathiAdari[3_2].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\SwatiSinha[5_3].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\tejaswitamultani[3_3].pdf
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\ThirumalaVaishnavi[3_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\valid_skills.txt
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\VatrapuVijayaRamaLakshmi[5_2].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\VijayaLakshmiPullari[3_0].docx
# C:/Users/SRUTHI/Desktop/amrutha/Chubb/Chubb\YaminiVerma[3_8].pdf

# %%
# Making table by using pandas DataFrame
import pandas as pd
df = pd.DataFrame({'phone nos':phone_nos,'education 1':education_1, 'education 2':education_2,'skills 1':skills_1, 
              'skills 2':skills_2, 'experience 1':experience_1, 'experiece 2':experience_2})

# %%
df.to_excel('C:/Users/SRUTHI/Desktop/amrutha/chubb2/extracted_data.xlsx',index=False)

# %%
df
# Out:
#      phone nos                                        education 1  \
# 0   8147767629  • be in information science from acharya insti...
# 1   8123694889
# 2   9710693660  bachelor of engineering in electronics and com...
# 3   9739700249                vcet vasai road – mumbai university
# 4   9824573997   diploma in mechanical engineering with first...
# ..         ...                                                ...
# 76  9766706900
# 77  9989908592                visvesvaraya college of engg & tech
# 78  9178931794  gudlavalleru engineering college– affiliated t...
# 79  9705069159  bachelor of technology in computer science and...
# 80  9179728760   bachelor of engineering in chemical cgpa: 652/10
#
#                                           education 2    skills 1 skills 2  \
# 0                                                               c     html
# 1                                                      javascript      css
# 2                                                          python     html
# 3                                                          python
# 4   govt polytechnic rajkot gujarat technological ...
# ..                                                ...         ...      ...
# 76                                                           html      css
# 77                       sri chaitanya junior college        html      css
# 78  bachelor’s in electrical and electronics engin...
# 79                                                           html      css
# 80  • responsible for maintaining and adding new f...  javascript   python
#
#                                          experience 1  \
# 0   [hashedin technologies bangalore as jr technic...
# 1   [ui developer may 2019 – present (client - ado...
# 2   [advisory system analyst ibm ltd – august 2017...
# 3
# 4   [: july 2017 to february 2020, primary job res...
# ..                                                ...
# 76  [nov 2017 - present, • actively working on mul...
# 77
# 78  [period: dec’18– jan’20, role: softwareenginee...
# 79  [bachelor of technology in computer science an...
# 80  [jun 2020 - present, unibuddy is a teched star...
#
#                                           experiece 2
# 0
# 1   [ui developer may 2018 – present (client - que...
# 2   [associate global technology solutions cogniza...
# 3
# 4   [: april 2015 to august 2016, : sales coordina...
# ..                                                ...
# 76
# 77
# 78  [period: may’16–nov’18, role: software enginee...
# 79
# 80  [nov 2018 - mar 2020, letstransport provides p...
#
# [81 rows x 7 columns]
